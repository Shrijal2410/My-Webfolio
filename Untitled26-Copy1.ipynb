# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\kumar\Downloads\Grade_data.csv")

# %%
df
# Out:
#        mid   Q1    Q2   HW1    HW2    end  Final Grade Grade
# 0     90.0  100  40.0  70.0  42.86  93.75        86.56     A
# 1    100.0  100  65.0  85.0  57.14  73.75        86.31     A
# 2     92.5  100  60.0  80.0  42.86  83.75        85.56     A
# 3     97.5  100  40.0  85.0  76.19  70.00        83.75     A
# 4     70.0   95  75.0  85.0  38.09  95.00        80.75     A
# ..     ...  ...   ...   ...    ...    ...          ...   ...
# 158   10.0   85  67.5  20.0   4.05   0.00         9.63     F
# 159    0.0    0  57.5  60.0  33.33   0.00         7.63     F
# 160    7.5    0   0.0   0.0   0.00   0.00         3.00     F
# 161    0.0    0   0.0   0.0   0.00   0.00         0.00     F
# 162    0.0    0   0.0   0.0   0.00   0.00         0.00     F
#
# [163 rows x 8 columns]

# %% [markdown]
# # q1

# %%
df.head(5)
# Out:
#      mid   Q1    Q2   HW1    HW2    end  Final Grade Grade
# 0   90.0  100  40.0  70.0  42.86  93.75        86.56     A
# 1  100.0  100  65.0  85.0  57.14  73.75        86.31     A
# 2   92.5  100  60.0  80.0  42.86  83.75        85.56     A
# 3   97.5  100  40.0  85.0  76.19  70.00        83.75     A
# 4   70.0   95  75.0  85.0  38.09  95.00        80.75     A

# %%
df.tail(5)
# Out:
#       mid  Q1    Q2   HW1    HW2  end  Final Grade Grade
# 158  10.0  85  67.5  20.0   4.05  0.0         9.63     F
# 159   0.0   0  57.5  60.0  33.33  0.0         7.63     F
# 160   7.5   0   0.0   0.0   0.00  0.0         3.00     F
# 161   0.0   0   0.0   0.0   0.00  0.0         0.00     F
# 162   0.0   0   0.0   0.0   0.00  0.0         0.00     F

# %% [markdown]
# ## q2

# %%
le = LabelEncoder()
df['Grade']=le.fit_transform(df['Grade'])

# %%
corri = df.corr()

# %%
corri
# Out:
#                   mid        Q1        Q2       HW1       HW2       end  \
# mid          1.000000  0.364243  0.405941  0.414565  0.313209  0.799242
# Q1           0.364243  1.000000  0.270686  0.320933  0.347420  0.479135
# Q2           0.405941  0.270686  1.000000  0.317591  0.151497  0.357931
# HW1          0.414565  0.320933  0.317591  1.000000  0.446609  0.413654
# HW2          0.313209  0.347420  0.151497  0.446609  1.000000  0.355081
# end          0.799242  0.479135  0.357931  0.413654  0.355081  1.000000
# Final Grade  0.936046  0.534124  0.458432  0.528293  0.445505  0.934001
# Grade       -0.222346 -0.000975 -0.188155 -0.076735 -0.110564 -0.167051
#
#              Final Grade     Grade
# mid             0.936046 -0.222346
# Q1              0.534124 -0.000975
# Q2              0.458432 -0.188155
# HW1             0.528293 -0.076735
# HW2             0.445505 -0.110564
# end             0.934001 -0.167051
# Final Grade     1.000000 -0.205600
# Grade          -0.205600  1.000000

# %% [markdown]
#     sns.heatmap(corri,annot=True)

# %%
sns.heatmap(corri,annot=True)
# Out:
# <AxesSubplot:>

# %%
#q3

# %%
sns.pairplot(df)

# %%
#q4

# %%
df['Grade'].value_counts()
# Out:
# 2    74
# 1    56
# 0    33
# Name: Grade, dtype: int64

# %%
df['Grade'].value_counts(1)
# Out:
# 2    0.453988
# 1    0.343558
# 0    0.202454
# Name: Grade, dtype: float64

# %%
count=pd.value_counts(df['Grade'])

# %%
count.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
count.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Grade'>

# %%
#5
